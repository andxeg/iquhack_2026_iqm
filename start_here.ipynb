# %% [markdown]
# # 🚀 Welcome IQM Challenge Submission
#
# Greetings from the **Team 17**! 💥
#
# **Members:**
# - Andrew Maciejunes
# - Jesse Webb
# - Andrew Norway
# - Vlad Gaylun
# - Andrei Chupakhin
#
#
# For more details about challenge and our solution see [README.md](./README.md) and [Team_17_iQuHACK_2026.pdf](./Team_17_iQuHACK_2026.pdf)

# %% [markdown]
# ## ⚙️ Step 1: Install dependencies
#
# Before running any code, please install the required Python packages.
#
# Open a **terminal** in the left sidebar (or add a new code cell below) and run:
#
# ```bash
# $ python -m pip install -r requirements.txt
#
# ```
#
# **NOTE!** This might take up to several minutes

# %% [markdown]
# ## ✅ Step 2: You're ready!
#
# Once dependencies are installed, you're ready to run entire pipline or notebooks.
#
# If you need help, check the `README.md` or explore other notebooks in this repository.
